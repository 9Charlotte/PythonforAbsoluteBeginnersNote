# %% [markdown]
# ## 如何安装 matplotlib

# %% [markdown]
# 首先需要打开命令控制台：
#
# 1. windwos：windows键盘 -> cmd
# 2. linux：ctrl + alt + t
#
# 然后输入：
# ```
# pip3 install matplotlib
#
# ```
#
# 等待安装结束即可。

# %% [markdown]
# 查看是否安装成功的方法有两个。
#
# 第一个是输入：

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -------------
# absl-py                      1.1.0
# anyio                        3.6.1
# apturl                       0.5.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asgiref                      3.5.2
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        21.4.0
# Babel                        2.10.3
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       5.0.0
# blinker                      1.4
# Brlapi                       0.8.3
# cachetools                   5.2.0
# certifi                      2020.6.20
# cffi                         1.15.0
# chardet                      4.0.0
# click                        8.0.3
# colorama                     0.4.4
# command-not-found            0.3
# cryptography                 3.4.8
# cupshelpers                  1.0
# ...

# %% [markdown]
# 可以看到所有的已经安装了的库。

# %% [markdown]
# 另一个方法则是进行导入：

# %%
import matplotlib

# %% [markdown]
# 如果已经安装了则不会报错，如果没有安装则会提示没有matplotlib库。
